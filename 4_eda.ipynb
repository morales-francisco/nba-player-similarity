# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from functions import *
from parameters import *
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv(path_processed_data +'/nba_all_stats_new_features_filtered.csv')

# %%
df = pd.read_csv(path_processed_data +'/nba_all_stats_new_features.csv')

# %%
df_per_game = df[stat_dataframes['per_game'].columns].query('Season == 2023')
df_advanced = df[stat_dataframes['advanced'].columns].query('Season == 2023')
df_play_by_play = df[stat_dataframes['play-by-play'].columns].query('Season == 2023')

# %% [markdown]
# Traditional stats

# %%
posiciones_validas = ['PG', 'SG', 'SF', 'PF', 'C']
df_filtrado = df_per_game[df_per_game['Pos'].isin(posiciones_validas)]

promedio_pts_por_pos = df_filtrado.groupby('Pos')['Pos'].count().sort_values(ascending=True)
fig, ax = plt.subplots()
ax.barh(promedio_pts_por_pos.index, promedio_pts_por_pos)

# Añade etiquetas y título
ax.set_xlabel('Cantidad de jugadores Posición')
ax.set_ylabel('Posición')
ax.set_title('Cantidad de jugadores por Posición')

# Muestra los valores en las barras
for index, value in enumerate(promedio_pts_por_pos):
    ax.text(value, index, f'{value:.2f}', ha='left', va='center', color='black')

# Elimina la cuadrícula de fondo y el eje x
ax.xaxis.set_visible(False)
ax.yaxis.grid(False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
# Muestra el gráfico
plt.show()

# %%
posiciones_validas = ['PG', 'SG', 'SF', 'PF', 'C']
df_filtrado = df_per_game[df_per_game['Pos'].isin(posiciones_validas)]

promedio_pts_por_pos = df_filtrado.groupby('Pos')['PTS'].mean().sort_values(ascending=True)
fig, ax = plt.subplots()
ax.barh(promedio_pts_por_pos.index, promedio_pts_por_pos)

# Añade etiquetas y título
ax.set_xlabel('Promedio de PTS')
ax.set_ylabel('Posición')
ax.set_title('Promedio de PTS por Posición')

# Muestra los valores en las barras
for index, value in enumerate(promedio_pts_por_pos):
    ax.text(value, index, f'{value:.2f}', ha='left', va='center', color='black')

# Elimina la cuadrícula de fondo y el eje x
ax.xaxis.set_visible(False)
ax.yaxis.grid(False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
# Muestra el gráfico
plt.show()

# %%
posiciones_validas = ['PG', 'SG', 'SF', 'PF', 'C']
df_filtrado = df_per_game[df_per_game['Pos'].isin(posiciones_validas)]
sns.boxplot(x='Pos', y='PTS', data=df_filtrado, order=posiciones_validas)

# Agregar título y etiquetas
plt.xlabel('Posición')
plt.ylabel('PTS')

# Mostrar el gráfico
plt.show()

# %%
posiciones_validas = ['PG', 'SG', 'SF', 'PF', 'C']
df_filtrado = df_per_game[df_per_game['Pos'].isin(posiciones_validas)]
sns.boxplot(x='Pos', y='ORB', data=df_filtrado, order=posiciones_validas)

# Agregar título y etiquetas
plt.xlabel('Posición')
plt.ylabel('ORB')

# Mostrar el gráfico
plt.show()

# %%
posiciones_validas = ['PG', 'SG', 'SF', 'PF', 'C']
df_filtrado = df_per_game[df_per_game['Pos'].isin(posiciones_validas)]

promedio_pts_por_pos = df_filtrado.groupby('Pos')['ORB'].mean().sort_values(ascending=True)

fig, ax = plt.subplots()
ax.barh(promedio_pts_por_pos.index, promedio_pts_por_pos)

# Añade etiquetas y título
ax.set_xlabel('Promedio de Rebotes Ofensivos')
ax.set_ylabel('Posición')
ax.set_title('Promedio de Rebotes Ofensivos por Posición')

# Muestra los valores en las barras
for index, value in enumerate(promedio_pts_por_pos):
    ax.text(value, index, f'{value:.2f}', ha='left', va='center', color='black')

# Elimina la cuadrícula de fondo y el eje x
ax.xaxis.set_visible(False)
ax.yaxis.grid(False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
# Muestra el gráfico
plt.show()

# %%
posiciones_validas = ['PG', 'SG', 'SF', 'PF', 'C']
df_filtrado = df_per_game[df_per_game['Pos'].isin(posiciones_validas)]
sns.boxplot(x='Pos', y='DRB', data=df_filtrado, order=posiciones_validas)

# Agregar título y etiquetas
plt.xlabel('Posición')
plt.ylabel('DRB')

# Mostrar el gráfico
plt.show()

# %%
posiciones_validas = ['PG', 'SG', 'SF', 'PF', 'C']
df_filtrado = df_per_game[df_per_game['Pos'].isin(posiciones_validas)]

promedio_pts_por_pos = df_filtrado.groupby('Pos')['DRB'].mean().sort_values(ascending=True)
fig, ax = plt.subplots()
ax.barh(promedio_pts_por_pos.index, promedio_pts_por_pos)

# Añade etiquetas y título
ax.set_xlabel('Promedio de Rebotes Defensivos')
ax.set_ylabel('Posición')
ax.set_title('Promedio de Rebotes Defensivos por Posición')

# Muestra los valores en las barras
for index, value in enumerate(promedio_pts_por_pos):
    ax.text(value, index, f'{value:.2f}', ha='left', va='center', color='black')

# Elimina la cuadrícula de fondo y el eje x
ax.xaxis.set_visible(False)
ax.yaxis.grid(False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
# Muestra el gráfico
plt.show()

# %%
posiciones_validas = ['PG', 'SG', 'SF', 'PF', 'C']
df_filtrado = df_per_game[df_per_game['Pos'].isin(posiciones_validas)]
sns.boxplot(x='Pos', y='AST', data=df_filtrado, order=posiciones_validas)

# Agregar título y etiquetas
plt.xlabel('Posición')
plt.ylabel('AST')

# Mostrar el gráfico
plt.show()

# %%
posiciones_validas = ['PG', 'SG', 'SF', 'PF', 'C']
df_filtrado = df_per_game[df_per_game['Pos'].isin(posiciones_validas)]

promedio_pts_por_pos = df_filtrado.groupby('Pos')['AST'].mean().sort_values(ascending=True)
fig, ax = plt.subplots()
ax.barh(promedio_pts_por_pos.index, promedio_pts_por_pos)

# Añade etiquetas y título
ax.set_xlabel('Promedio de Asistencias')
ax.set_ylabel('Posición')
ax.set_title('Promedio de Asistencias por Posición')

# Muestra los valores en las barras
for index, value in enumerate(promedio_pts_por_pos):
    ax.text(value, index, f'{value:.2f}', ha='left', va='center', color='black')

# Elimina la cuadrícula de fondo y el eje x
ax.xaxis.set_visible(False)
ax.yaxis.grid(False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
# Muestra el gráfico
plt.show()

# %%
posiciones_validas = ['PG', 'SG', 'SF', 'PF', 'C']
df_filtrado = df_per_game[df_per_game['Pos'].isin(posiciones_validas)]
sns.boxplot(x='Pos', y='STL', data=df_filtrado, order=posiciones_validas)

# Agregar título y etiquetas
plt.xlabel('Posición')
plt.ylabel('STL')

# Mostrar el gráfico
plt.show()

# %%
posiciones_validas = ['PG', 'SG', 'SF', 'PF', 'C']
df_filtrado = df_per_game[df_per_game['Pos'].isin(posiciones_validas)]

promedio_pts_por_pos = df_filtrado.groupby('Pos')['STL'].mean().sort_values(ascending=True)
fig, ax = plt.subplots()
ax.barh(promedio_pts_por_pos.index, promedio_pts_por_pos)

# Añade etiquetas y título
ax.set_xlabel('Promedio de Robos')
ax.set_ylabel('Posición')
ax.set_title('Promedio de Robos por Posición')

# Muestra los valores en las barras
for index, value in enumerate(promedio_pts_por_pos):
    ax.text(value, index, f'{value:.2f}', ha='left', va='center', color='black')

# Elimina la cuadrícula de fondo y el eje x
ax.xaxis.set_visible(False)
ax.yaxis.grid(False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
# Muestra el gráfico
plt.show()

# %%
posiciones_validas = ['PG', 'SG', 'SF', 'PF', 'C']
df_filtrado = df_per_game[df_per_game['Pos'].isin(posiciones_validas)]
sns.boxplot(x='Pos', y='BLK', data=df_filtrado, order=posiciones_validas)

# Agregar título y etiquetas
plt.xlabel('Posición')
plt.ylabel('BLK')

# Mostrar el gráfico
plt.show()

# %%
posiciones_validas = ['PG', 'SG', 'SF', 'PF', 'C']
df_filtrado = df_per_game[df_per_game['Pos'].isin(posiciones_validas)]

promedio_pts_por_pos = df_filtrado.groupby('Pos')['BLK'].mean().sort_values(ascending=True)
fig, ax = plt.subplots()
ax.barh(promedio_pts_por_pos.index, promedio_pts_por_pos)

# Añade etiquetas y título
ax.set_xlabel('Promedio de Tapas')
ax.set_ylabel('Posición')
ax.set_title('Promedio de Tapas por Posición')

# Muestra los valores en las barras
for index, value in enumerate(promedio_pts_por_pos):
    ax.text(value, index, f'{value:.2f}', ha='left', va='center', color='black')

# Elimina la cuadrícula de fondo y el eje x
ax.xaxis.set_visible(False)
ax.yaxis.grid(False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
# Muestra el gráfico
plt.show()

# %%
heatmap_correlation(df_per_game)
# Out:
# Correlation Table
#              Age         G        GS        MP        FG       FGA       FG%  \
# Age     1.000000 -0.026310  0.064265  0.107422  0.061230  0.050822  0.055271
# G      -0.026310  1.000000  0.592537  0.575921  0.405429  0.395850  0.143142
# GS      0.064265  0.592537  1.000000  0.859473  0.735560  0.717956  0.153553
# MP      0.107422  0.575921  0.859473  1.000000  0.873432  0.877727  0.071804
# FG      0.061230  0.405429  0.735560  0.873432  1.000000  0.974847  0.168873
# FGA     0.050822  0.395850  0.717956  0.877727  0.974847  1.000000 -0.019607
# FG%     0.055271  0.143142  0.153553  0.071804  0.168873 -0.019607  1.000000
# 3P      0.151924  0.328604  0.480231  0.647076  0.607723  0.714672 -0.344879
# 3PA     0.122775  0.323956  0.489487  0.658426  0.621476  0.743957 -0.407997
# 3P%     0.129568  0.099253  0.029608  0.134663  0.128328  0.180601 -0.222593
# 2P      0.005979  0.342680  0.673746  0.765006  0.935690  0.858101  0.355819
# ...

# %%
columns = ['3P%', '2P%', 'eFG%', 'FT%', 'ORB', 'DRB', 'AST', 'STL', 'BLK', 'TOV', 'PTS']
heatmap_correlation(df_per_game, columns=columns)
# Out:
# Correlation Table
#            3P%       2P%      eFG%       FT%       ORB       DRB       AST  \
# 3P%   1.000000 -0.228483  0.050791  0.289958 -0.361046 -0.093066  0.133140
# 2P%  -0.228483  1.000000  0.718481 -0.131320  0.418015  0.243772 -0.169038
# eFG%  0.050791  0.718481  1.000000 -0.105202  0.438748  0.325900 -0.089296
# FT%   0.289958 -0.131320 -0.105202  1.000000 -0.242722 -0.013475  0.224800
# ORB  -0.361046  0.418015  0.438748 -0.242722  1.000000  0.678034  0.006261
# DRB  -0.093066  0.243772  0.325900 -0.013475  0.678034  1.000000  0.425441
# AST   0.133140 -0.169038 -0.089296  0.224800  0.006261  0.425441  1.000000
# STL   0.080594 -0.109175 -0.006645  0.215978  0.163868  0.389962  0.654586
# BLK  -0.195756  0.363649  0.396679 -0.165365  0.636534  0.581397  0.019311
# TOV   0.086084 -0.060395  0.009408  0.182785  0.217979  0.639090  0.834800
# PTS   0.167187 -0.013885  0.113143  0.298961  0.209865  0.665440  0.706122
#
#            STL       BLK       TOV       PTS
# ...

# %% [markdown]
# Advanced stats

# %%
posiciones_validas = ['PG', 'SG', 'SF', 'PF', 'C']
df_filtrado = df_advanced[df_advanced['Pos'].isin(posiciones_validas)]
sns.boxplot(x='Pos', y='PER', data=df_filtrado, order=posiciones_validas)

# Agregar título y etiquetas
plt.xlabel('Posición')
plt.ylabel('PER')

# Mostrar el gráfico
plt.show()

# %%
posiciones_validas = ['PG', 'SG', 'SF', 'PF', 'C']
df_filtrado = df_advanced[df_per_game['Pos'].isin(posiciones_validas)]

promedio_pts_por_pos = df_filtrado.groupby('Pos')['PER'].mean().sort_values(ascending=True)
fig, ax = plt.subplots()
ax.barh(promedio_pts_por_pos.index, promedio_pts_por_pos)

# Añade etiquetas y título
ax.set_xlabel('Promedio de PER')
ax.set_ylabel('Posición')
ax.set_title('Promedio de PER por Posición')

# Muestra los valores en las barras
for index, value in enumerate(promedio_pts_por_pos):
    ax.text(value, index, f'{value:.2f}', ha='left', va='center', color='black')

# Elimina la cuadrícula de fondo y el eje x
ax.xaxis.set_visible(False)
ax.yaxis.grid(False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
# Muestra el gráfico
plt.show()

# %%
posiciones_validas = ['PG', 'SG', 'SF', 'PF', 'C']
df_filtrado = df_advanced[df_advanced['Pos'].isin(posiciones_validas)]
sns.boxplot(x='Pos', y='DBPM', data=df_filtrado, order=posiciones_validas)

# Agregar título y etiquetas
plt.xlabel('Posición')
plt.ylabel('DBPM')

# Mostrar el gráfico
plt.show()

# %%
posiciones_validas = ['PG', 'SG', 'SF', 'PF', 'C']
df_filtrado = df_advanced[df_per_game['Pos'].isin(posiciones_validas)]

promedio_pts_por_pos = df_filtrado.groupby('Pos')['DBPM'].mean().sort_values(ascending=True)
fig, ax = plt.subplots()
ax.barh(promedio_pts_por_pos.index, promedio_pts_por_pos)

# Añade etiquetas y título
ax.set_xlabel('Promedio de DBPM')
ax.set_ylabel('Posición')
ax.set_title('Promedio de DBPM por Posición')

# Muestra los valores en las barras
for index, value in enumerate(promedio_pts_por_pos):
    ax.text(value, index, f'{value:.2f}', ha='left', va='center', color='black')

# Elimina la cuadrícula de fondo y el eje x
ax.xaxis.set_visible(False)
ax.yaxis.grid(False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
# Muestra el gráfico
plt.show()

# %%
posiciones_validas = ['PG', 'SG', 'SF', 'PF', 'C']
df_filtrado = df_advanced[df_per_game['Pos'].isin(posiciones_validas)]

promedio_pts_por_pos = df_filtrado.groupby('Pos')['OBPM'].mean().sort_values(ascending=True)
fig, ax = plt.subplots()
ax.barh(promedio_pts_por_pos.index, promedio_pts_por_pos)

# Añade etiquetas y título
ax.set_xlabel('Promedio de OBPM')
ax.set_ylabel('Posición')
ax.set_title('Promedio de OBPM por Posición')

# Muestra los valores en las barras
for index, value in enumerate(promedio_pts_por_pos):
    ax.text(value, index, f'{value:.2f}', ha='left', va='center', color='black')

# Elimina la cuadrícula de fondo y el eje x
ax.xaxis.set_visible(False)
ax.yaxis.grid(False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
# Muestra el gráfico
plt.show()

# %%
heatmap_correlation(df_advanced)
# Out:
# Correlation Table
#              Age         G        MP       PER       TS%      3PAr       FTr  \
# Age     1.000000  0.080564  0.133624  0.076293  0.128288  0.086913 -0.005873
# G       0.080564  1.000000  0.649715  0.261155  0.292537 -0.057960  0.034522
# MP      0.133624  0.649715  1.000000  0.406181  0.273703 -0.044961  0.067889
# PER     0.076293  0.261155  0.406181  1.000000  0.620201 -0.259542  0.466923
# TS%     0.128288  0.292537  0.273703  0.620201  1.000000 -0.169310  0.334312
# 3PAr    0.086913 -0.057960 -0.044961 -0.259542 -0.169310  1.000000 -0.358997
# FTr    -0.005873  0.034522  0.067889  0.466923  0.334312 -0.358997  1.000000
# ORB%   -0.071286 -0.049020 -0.173867  0.201337  0.113087 -0.578434  0.272707
# DRB%    0.005879  0.062714  0.036639  0.327721  0.184506 -0.381440  0.134528
# TRB%   -0.023689  0.023332 -0.052749  0.322244  0.182665 -0.528219  0.217854
# AST%    0.149977  0.125304  0.430489  0.273742 -0.028555 -0.040705  0.007003
# ...

# %%
columns = ['TS%', 'ORB%', 'DRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'OBPM', 'DBPM']
heatmap_correlation(df_advanced, columns=columns)
# Out:
# Correlation Table
#            TS%      ORB%      DRB%      AST%      STL%      BLK%      TOV%  \
# TS%   1.000000  0.366801  0.350468 -0.118607 -0.144093  0.320599  0.031925
# ORB%  0.366801  1.000000  0.664347 -0.353744 -0.045474  0.626953  0.227223
# DRB%  0.350468  0.664347  1.000000 -0.114177 -0.130137  0.528339  0.222010
# AST% -0.118607 -0.353744 -0.114177  1.000000  0.219414 -0.303371  0.279152
# STL% -0.144093 -0.045474 -0.130137  0.219414  1.000000 -0.064564  0.078444
# BLK%  0.320599  0.626953  0.528339 -0.303371 -0.064564  1.000000  0.185717
# TOV%  0.031925  0.227223  0.222010  0.279152  0.078444  0.185717  1.000000
# OBPM  0.560457  0.012355  0.224329  0.475995  0.031596  0.004169 -0.226446
# DBPM  0.293982  0.249192  0.351223  0.092213  0.483427  0.443218  0.251640
#
#           OBPM      DBPM
# TS%   0.560457  0.293982
# ORB%  0.012355  0.249192
# DRB%  0.224329  0.351223
# AST%  0.475995  0.092213
# STL%  0.031596  0.483427
# BLK%  0.004169  0.443218
# ...

# %% [markdown]
# Play-by-play stats

# %%
posiciones_validas = ['PG', 'SG', 'SF', 'PF', 'C']
df_filtrado = df_play_by_play[df_play_by_play['Pos'].isin(posiciones_validas)]
sns.boxplot(x='Pos', y='LostBall', data=df_filtrado, order=posiciones_validas)

# Agregar título y etiquetas
plt.xlabel('Posición')
plt.ylabel('LostBall')

# Mostrar el gráfico
plt.show()

# %%
posiciones_validas = ['PG', 'SG', 'SF', 'PF', 'C']
df_filtrado = df_play_by_play[df_play_by_play['Pos'].isin(posiciones_validas)]

promedio_pts_por_pos = df_filtrado.groupby('Pos')['LostBall'].mean().sort_values(ascending=True)
fig, ax = plt.subplots()
ax.barh(promedio_pts_por_pos.index, promedio_pts_por_pos)

# Añade etiquetas y título
ax.set_xlabel('Promedio de Pérdidas a causa pérdida de Balón')
ax.set_ylabel('Posición')
ax.set_title('Promedio de Pérdidas a causa de pérdida de Balón por Posición')

# Muestra los valores en las barras
for index, value in enumerate(promedio_pts_por_pos):
    ax.text(value, index, f'{value:.2f}', ha='left', va='center', color='black')

# Elimina la cuadrícula de fondo y el eje x
ax.xaxis.set_visible(False)
ax.yaxis.grid(False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
# Muestra el gráfico
plt.show()

# %%
posiciones_validas = ['PG', 'SG', 'SF', 'PF', 'C']
df_filtrado = df_play_by_play[df_play_by_play['Pos'].isin(posiciones_validas)]
sns.boxplot(x='Pos', y='BadPass', data=df_filtrado, order=posiciones_validas)

# Agregar título y etiquetas
plt.xlabel('Posición')
plt.ylabel('BadPass')

# Mostrar el gráfico
plt.show()

# %%
posiciones_validas = ['PG', 'SG', 'SF', 'PF', 'C']
df_filtrado = df_play_by_play[df_play_by_play['Pos'].isin(posiciones_validas)]

promedio_pts_por_pos = df_filtrado.groupby('Pos')['BadPass'].mean().sort_values(ascending=True)
fig, ax = plt.subplots()
ax.barh(promedio_pts_por_pos.index, promedio_pts_por_pos)

# Añade etiquetas y título
ax.set_xlabel('Promedio de Pérdidas mal pase')
ax.set_ylabel('Posición')
ax.set_title('Promedio de Pérdidas a causa de un mal pase por Posición')

# Muestra los valores en las barras
for index, value in enumerate(promedio_pts_por_pos):
    ax.text(value, index, f'{value:.2f}', ha='left', va='center', color='black')

# Elimina la cuadrícula de fondo y el eje x
ax.xaxis.set_visible(False)
ax.yaxis.grid(False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
# Muestra el gráfico
plt.show()

# %%
posiciones_validas = ['PG', 'SG', 'SF', 'PF', 'C']
df_filtrado = df_play_by_play[df_play_by_play['Pos'].isin(posiciones_validas)]
sns.boxplot(x='Pos', y='PGA', data=df_filtrado, order=posiciones_validas)

# Agregar título y etiquetas
plt.xlabel('Posición')
plt.ylabel('PGA')

# Mostrar el gráfico
plt.show()

# %%
posiciones_validas = ['PG', 'SG', 'SF', 'PF', 'C']
df_filtrado = df_play_by_play[df_play_by_play['Pos'].isin(posiciones_validas)]

promedio_pts_por_pos = df_filtrado.groupby('Pos')['PGA'].mean().sort_values(ascending=True)
fig, ax = plt.subplots()
ax.barh(promedio_pts_por_pos.index, promedio_pts_por_pos)

# Añade etiquetas y título
ax.set_xlabel('Promedio de Pérdidas mal pase')
ax.set_ylabel('Posición')
ax.set_title('Promedio de puntos generados por Asistencias por Posición')

# Muestra los valores en las barras
for index, value in enumerate(promedio_pts_por_pos):
    ax.text(value, index, f'{value:.2f}', ha='left', va='center', color='black')

# Elimina la cuadrícula de fondo y el eje x
ax.xaxis.set_visible(False)
ax.yaxis.grid(False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
# Muestra el gráfico
plt.show()

# %%
posiciones_validas = ['PG', 'SG', 'SF', 'PF', 'C']
df_filtrado = df_play_by_play[df_play_by_play['Pos'].isin(posiciones_validas)]

promedio_pts_por_pos = df_filtrado.groupby('Pos')['Blkd'].mean().sort_values(ascending=True)
fig, ax = plt.subplots()
ax.barh(promedio_pts_por_pos.index, promedio_pts_por_pos)

# Añade etiquetas y título
ax.set_xlabel('Promedio de Pérdidas mal pase')
ax.set_ylabel('Posición')
ax.set_title('Promedio de tiros encestados al recibir falta por Posición')

# Muestra los valores en las barras
for index, value in enumerate(promedio_pts_por_pos):
    ax.text(value, index, f'{value:.2f}', ha='left', va='center', color='black')

# Elimina la cuadrícula de fondo y el eje x
ax.xaxis.set_visible(False)
ax.yaxis.grid(False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
# Muestra el gráfico
plt.show()

# %%
heatmap_correlation(df_play_by_play)
# Out:
# Correlation Table
#                            Age         G        MP       PG%       SG%  \
# Age                   1.000000 -0.026310  0.107422  0.043811 -0.125350
# G                    -0.026310  1.000000  0.575921 -0.018109  0.030663
# MP                    0.107422  0.575921  1.000000  0.113372  0.094459
# PG%                   0.043811 -0.018109  0.113372  1.000000  0.007114
# SG%                  -0.125350  0.030663  0.094459  0.007114  1.000000
# SF%                  -0.053017  0.074411  0.053153 -0.374425  0.128132
# PF%                   0.070612  0.008866 -0.030944 -0.396853 -0.438585
# C%                    0.027828 -0.061712 -0.178284 -0.342846 -0.441001
# OnCourt               0.236546  0.297108  0.327402  0.008125 -0.066800
# On-Off                0.116357  0.257815  0.402312  0.017816 -0.053220
# BadPass               0.130832  0.267858  0.693833  0.421851  0.114928
# LostBall             -0.047737  0.311302  0.715722  0.140938  0.089788
# ...

# %%
columns = ['OnCourt', 'On-Off', 'BadPass', 'LostBall', 'Fouls Commited Shoot', 'Fouls Commited Off', 'Fouls Drawn Shoot', 'Fouls Drawn Off', 'PGA', 'And1', 'Blkd']
heatmap_correlation(df_play_by_play, columns=columns)
# Out:
# Correlation Table
#                        OnCourt    On-Off   BadPass  LostBall  \
# OnCourt               1.000000  0.769433  0.173312  0.166686
# On-Off                0.769433  1.000000  0.279185  0.252847
# BadPass               0.173312  0.279185  1.000000  0.700825
# LostBall              0.166686  0.252847  0.700825  1.000000
# Fouls Commited Shoot  0.138223  0.219299  0.223585  0.318871
# Fouls Commited Off    0.129840  0.194461  0.253478  0.459822
# Fouls Drawn Shoot     0.236326  0.330758  0.587562  0.811649
# Fouls Drawn Off       0.169821  0.194981  0.293848  0.129376
# PGA                   0.247613  0.317022  0.901548  0.665988
# And1                  0.234048  0.331023  0.572712  0.783385
# Blkd                  0.104769  0.223551  0.616880  0.812099
#
#                       Fouls Commited Shoot  Fouls Commited Off  \
# OnCourt                           0.138223            0.129840
# On-Off                            0.219299            0.194461
# ...

# %% [markdown]
# New features

# %%
columns = ['versatility_score', 'blocks_per_foul', 'and1_efectiveness', 'ast_per_tov', 'ord_drb', 'net_pm', '3pt_percentage', '2pt_percentage', 'fouls_efficiency', 'points_shot_attempt',	'starting_percentage']
heatmap_correlation(df, columns=columns)
# Out:
# Correlation Table
#                      versatility_score  blocks_per_foul  and1_efectiveness  \
# versatility_score             1.000000        -0.249184          -0.067536
# blocks_per_foul              -0.249184         1.000000           0.033173
# and1_efectiveness            -0.067536         0.033173           1.000000
# ast_per_tov                  -0.039656        -0.088660           0.052186
# ord_drb                      -0.156096         0.249507           0.054917
# net_pm                       -0.087940         0.085506           0.057667
# 3pt_percentage                0.390932        -0.379669          -0.164390
# 2pt_percentage               -0.390934         0.379670           0.164390
# fouls_efficiency             -0.142606         0.605610           0.076372
# points_shot_attempt          -0.202782         0.296847           0.222959
# starting_percentage          -0.133502         0.182669           0.055085
#
# ...

# %% [markdown]
# All features

# %%
columns = ['3P%', '2P%', 'eFG%', 'FT%', 'ORB', 'DRB', 'AST', 'STL', 'BLK', 'TOV', 'PTS', 'TS%', 'ORB%', 'DRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'OBPM', 'DBPM',
'OnCourt', 'On-Off', 'BadPass', 'LostBall', 'Fouls Commited Shoot', 'Fouls Commited Off', 'Fouls Drawn Shoot', 'Fouls Drawn Off', 'PGA', 'And1', 'Blkd',
 'versatility_score', 'blocks_per_foul', 'and1_efectiveness', 'ord_drb', 'net_pm', '3pt_percentage', '2pt_percentage','ast_per_tov', 'fouls_efficiency', 'points_shot_attempt', 'starting_percentage']
heatmap_correlation(df, columns=columns)
# Out:
# Correlation Table
#                            3P%       2P%      eFG%       FT%       ORB  \
# 3P%                   1.000000 -0.228483  0.050791  0.289958 -0.361046
# 2P%                  -0.228483  1.000000  0.718481 -0.131320  0.418015
# eFG%                  0.050791  0.718481  1.000000 -0.105202  0.438748
# FT%                   0.289958 -0.131320 -0.105202  1.000000 -0.242722
# ORB                  -0.361046  0.418015  0.438748 -0.242722  1.000000
# DRB                  -0.093066  0.243772  0.325900 -0.013475  0.678034
# AST                   0.133140 -0.169038 -0.089296  0.224800  0.006261
# STL                   0.080594 -0.109175 -0.006645  0.215978  0.163868
# BLK                  -0.195756  0.363649  0.396679 -0.165365  0.636534
# TOV                   0.086084 -0.060395  0.009408  0.182785  0.217979
# PTS                   0.167187 -0.013885  0.113143  0.298961  0.209865
# TS%                   0.104401  0.682699  0.955176  0.079922  0.419630
# ...
