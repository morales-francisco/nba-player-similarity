# %%
from parameters import *
from functions import *

# %%
df_per_game = get_stats('per_game')
df_per_game
# Out:
# Season 2013 - Shape (596, 30)
# Season 2014 - Shape (635, 30)
# Season 2015 - Shape (675, 30)
# Season 2016 - Shape (601, 30)
# Season 2017 - Shape (619, 30)
# Season 2018 - Shape (690, 30)
# Season 2019 - Shape (734, 30)
# Season 2020 - Shape (677, 30)
# Season 2021 - Shape (731, 30)
# Season 2022 - Shape (842, 30)
# Season 2023 - Shape (705, 30)
# Column names - Done
# Data saved in data/raw/nba_per_game_2013_2023.csv
#                 Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  ORB  \
# 0     Precious Achiuwa   C  23  TOR  55  12  20.7  3.6   7.3  .485  ...  1.8
# 1         Steven Adams   C  29  MEM  42  42  27.0  3.7   6.3  .597  ...  5.1
# 2          Bam Adebayo   C  25  MIA  75  75  34.6  8.0  14.9  .540  ...  2.5
# 3         Ochai Agbaji  SG  22  UTA  59  22  20.5  2.8   6.5  .427  ...  0.7
# 4         Santi Aldama  PF  22  MEM  77  20  21.8  3.2   6.8  .470  ...  1.1
# ...                ...  ..  ..  ...  ..  ..   ...  ...   ...   ...  ...  ...
# ...

# %%
df_play_by_play = get_stats('play-by-play')
df_play_by_play
# Out:
# Season 2013 - Shape (596, 23)
# Season 2014 - Shape (635, 23)
# Season 2015 - Shape (675, 23)
# Season 2016 - Shape (601, 23)
# Season 2017 - Shape (619, 23)
# Season 2018 - Shape (690, 23)
# Season 2019 - Shape (734, 23)
# Season 2020 - Shape (677, 23)
# Season 2021 - Shape (731, 23)
# Season 2022 - Shape (842, 23)
# Season 2023 - Shape (705, 23)
# Column names - Done
# Data saved in data/raw/nba_play-by-play_2013_2023.csv
#                 Player Pos Age   Tm   G    MP  PG%  SG%  SF%  PF%  ...  \
# 0     Precious Achiuwa   C  23  TOR  55  1140  NaN  NaN  NaN   17  ...
# 1         Steven Adams   C  29  MEM  42  1133  NaN  NaN  NaN  NaN  ...
# 2          Bam Adebayo   C  25  MIA  75  2598  NaN  NaN  NaN  NaN  ...
# 3         Ochai Agbaji  SG  22  UTA  59  1209   38   40   20    3  ...
# 4         Santi Aldama  PF  22  MEM  77  1682  NaN  NaN    2   69  ...
# ...                ...  ..  ..  ...  ..   ...  ...  ...  ...  ...  ...
# ...

# %%
df_advanced = get_stats('advanced')
df_advanced
# Out:
# Season 2013 - Shape (596, 29)
# Season 2014 - Shape (635, 29)
# Season 2015 - Shape (675, 29)
# Season 2016 - Shape (601, 29)
# Season 2017 - Shape (619, 29)
# Season 2018 - Shape (690, 29)
# Season 2019 - Shape (734, 29)
# Season 2020 - Shape (677, 29)
# Season 2021 - Shape (731, 29)
# Season 2022 - Shape (842, 29)
# Season 2023 - Shape (705, 29)
# Column names - Done
# Data saved in data/raw/nba_advanced_2013_2023.csv
#                 Player Pos Age   Tm   G    MP   PER   TS%  3PAr   FTr  ...  \
# 0     Precious Achiuwa   C  23  TOR  55  1140  15.2  .554  .267  .307  ...
# 1         Steven Adams   C  29  MEM  42  1133  17.5  .564  .004  .490  ...
# 2          Bam Adebayo   C  25  MIA  75  2598  20.1  .592  .011  .361  ...
# 3         Ochai Agbaji  SG  22  UTA  59  1209   9.5  .561  .591  .179  ...
# 4         Santi Aldama  PF  22  MEM  77  1682  13.9  .591  .507  .274  ...
# ...                ...  ..  ..  ...  ..   ...   ...   ...   ...   ...  ...
# ...

# %%
df_contract = get_contracts()
df_contract
# Out:
# Column names - done
# Data saved in data/0_raw/nba_contracts.csv
# /Users/montevideolabs/Documents/Code/functions.py:91: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table_html))[0]
#                 Player   Tm 2023-24 Salary 2024-25 Salary 2025-26 Salary  \
# 0        Stephen Curry  GSW    $51,915,615    $55,761,216    $59,606,817
# 1         Kevin Durant  PHO    $47,649,433    $51,179,021    $54,708,609
# 2         Nikola Jokić  DEN    $47,607,350    $51,415,938    $55,224,526
# 3          Joel Embiid  PHI    $47,607,350    $51,415,938    $55,224,526
# 4         LeBron James  LAL    $47,607,350    $51,415,938            NaN
# ..                 ...  ...            ...            ...            ...
# 521       Nerlens Noel  SAC       $300,000            NaN            NaN
# ...

# %%
df_players_bio = get_players_bio()
df_players_bio
# Out:
# Data gathering - done
# Data saved in data/raw/nba_players_bio.csv
#                   Name                                           Position  \
# 0        Stephen Curry                                     [ Point Guard]
# 1         Kevin Durant  [ Small Forward, Power Forward, and Shooting G...
# 2         Nikola Jokić                                          [ Center]
# 3          Joel Embiid                                          [ Center]
# 4         LeBron James  [ Small Forward, Power Forward, Point Guard, C...
# ..                 ...                                                ...
# 479      Lamar Stevens                 [ Power Forward and Small Forward]
# 480       Nerlens Noel                        [ Center and Power Forward]
# 481       Didi Louzada                [ Small Forward and Shooting Guard]
# 482      Neemias Queta                                          [ Center]
# 483  Demetrius Jackson                                     [ Point Guard]
#
# ...
