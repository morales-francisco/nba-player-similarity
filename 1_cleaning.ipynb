# %%
from functions import *
from parameters import *

# %%
df_per_game = clean_data_stats('per_game')
df_per_game
# Out:
# Reading df - Done
# Data cleaning - Done
# Data saved in data/1_cleaned/nba_per_game_2013_2023_cleaned.csv
#                 Player Pos Age   Tm   G  GS    MP   FG  FGA    FG%  ...  ORB  \
# 0     Precious Achiuwa   C  23  TOR  55  12  20.7  3.6  7.3  0.485  ...  1.8
# 468    Larry Nance Jr.   C  30  NOP  65   1  21.2  2.9  4.7  0.610  ...  1.6
# 489        Chuma Okeke  SF  24  ORL  27   8  19.2  1.6  4.5  0.352  ...  1.0
# 488      Royce O'Neale  SF  29  BRK  76  53  31.7  3.0  7.8  0.386  ...  0.7
# 485       Jordan Nwora  SF  24  TOT  62  14  19.2  3.1  7.2  0.436  ...  0.8
# ...                ...  ..  ..  ...  ..  ..   ...  ...  ...    ...  ...  ...
# 7104       Drew Gooden   C  31  MIL  16   0   9.4  1.3  3.8  0.328  ...  0.8
# 7103     Manu Ginóbili  SG  35  SAS  60   0  23.2  3.8  9.0  0.425  ...  0.5
# 7102        Taj Gibson  PF  27  CHI  65   5  22.4  3.3  6.8  0.485  ...  1.9
# 7101     Daniel Gibson  PG  26  CLE  46   3  20.0  1.8  5.4  0.340  ...  0.1
# ...

# %%
df_play_by_play = clean_data_stats('play-by-play')
df_play_by_play
# Out:
# Reading df - Done
# Data cleaning - Done
# Data saved in data/1_cleaned/nba_play-by-play_2013_2023_cleaned.csv
#                 Player Pos Age   Tm     G     MP   PG%   SG%   SF%   PF%  ...  \
# 0     Precious Achiuwa   C  23  TOR  55.0  20.73  0.00  0.00  0.00  0.17  ...
# 468    Larry Nance Jr.   C  30  NOP  65.0  21.25  0.00  0.00  0.00  0.19  ...
# 489        Chuma Okeke  SF  24  ORL  27.0  19.19  0.05  0.52  0.40  0.03  ...
# 488      Royce O'Neale  SF  29  BRK  76.0  31.70  0.00  0.24  0.61  0.15  ...
# 485       Jordan Nwora  SF  24  TOT  62.0  19.16  0.00  0.04  0.40  0.56  ...
# ...                ...  ..  ..  ...   ...    ...   ...   ...   ...   ...  ...
# 7104       Drew Gooden   C  31  MIL  16.0   9.44  0.00  0.00  0.00  0.25  ...
# 7103     Manu Ginóbili  SG  35  SAS  60.0  23.22  0.03  0.76  0.21  0.00  ...
# 7102        Taj Gibson  PF  27  CHI  65.0  22.45  0.00  0.00  0.00  0.85  ...
# 7101     Daniel Gibson  PG  26  CLE  46.0  19.98  1.00  0.00  0.00  0.00  ...
# ...

# %%
df_advanced = clean_data_stats('advanced')
df_advanced
# Out:
# Reading df - Done
# Data cleaning - Done
# Data saved in data/1_cleaned/nba_advanced_2013_2023_cleaned.csv
#                 Player Pos Age   Tm   G    MP   PER    TS%   3PAr    FTr  ...  \
# 0     Precious Achiuwa   C  23  TOR  55  1140  15.2  0.554  0.267  0.307  ...
# 468    Larry Nance Jr.   C  30  NOP  65  1381  16.0  0.649  0.138  0.259  ...
# 489        Chuma Okeke  SF  24  ORL  27   518   9.1  0.488  0.705  0.172  ...
# 488      Royce O'Neale  SF  29  BRK  76  2409   9.2  0.538  0.707  0.116  ...
# 485       Jordan Nwora  SF  24  TOT  62  1188  12.2  0.561  0.474  0.193  ...
# ...                ...  ..  ..  ...  ..   ...   ...    ...    ...    ...  ...
# 7104       Drew Gooden   C  31  MIL  16   151   7.7  0.382  0.082  0.262  ...
# 7103     Manu Ginóbili  SG  35  SAS  60  1393  19.0  0.560  0.436  0.382  ...
# 7102        Taj Gibson  PF  27  CHI  65  1459  14.4  0.518  0.009  0.297  ...
# 7101     Daniel Gibson  PG  26  CLE  46   919   7.7  0.475  0.660  0.150  ...
# ...

# %%
df_contracts = clean_data_contracts('contracts')
df_contracts
# Out:
# Data cleaning - done
# Data saved in data/1_cleaned/nba_contracts_cleaned.csv
#                 Player   Tm 2023-24 Salary 2024-25 Salary 2025-26 Salary  \
# 0        Stephen Curry  GSW    $51,915,615    $55,761,216    $59,606,817
# 1         Kevin Durant  PHO    $47,649,433    $51,179,021    $54,708,609
# 2         Nikola Jokić  DEN    $47,607,350    $51,415,938    $55,224,526
# 3          Joel Embiid  PHI    $47,607,350    $51,415,938    $55,224,526
# 4         LeBron James  LAL    $47,607,350    $51,415,938     Free Agent
# ..                 ...  ...            ...            ...            ...
# 521       Nerlens Noel  SAC       $300,000     Free Agent     Free Agent
# 522       Didi Louzada  POR       $268,032       $268,032       $268,032
# 523      Neemias Queta  SAC       $250,000     Free Agent     Free Agent
# 524        Danny Green  PHI       $200,000     Free Agent     Free Agent
# 525  Demetrius Jackson  BOS        $92,857     Free Agent     Free Agent
#
# ...

# %%
df_player_bio = clean_data_players_bio('players_bio')
df_player_bio
# Out:
# Data cleaning - done
# Data saved in data/1_cleaned/nba_players_bio_cleaned.csv
#                   Name                                           Position  \
# 0        Stephen Curry                                        Point Guard
# 1         Kevin Durant   Small Forward, Power Forward, and Shooting Guard
# 2         Nikola Jokić                                             Center
# 3          Joel Embiid                                             Center
# 4         LeBron James   Small Forward, Power Forward, Point Guard, Ce...
# ..                 ...                                                ...
# 478        Malik Fitts                                      Power Forward
# 480       Nerlens Noel                           Center and Power Forward
# 481       Didi Louzada                   Small Forward and Shooting Guard
# 482      Neemias Queta                                             Center
# 483  Demetrius Jackson                                        Point Guard
#
# ...
